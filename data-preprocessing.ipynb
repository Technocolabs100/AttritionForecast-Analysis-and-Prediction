# %% [markdown]
# # First Task

# %% [markdown]
# ### data exploration
# first, let's explore the data to understand it better. first, we import the libraries we need for our work

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# we now import our dataset, we load our csv file into a pandas dataframme, and we explore some preliminary informations about
# our dataset by using df.info() : the number of columns, column labels, column data types, memory usage, range index, and the number of cells in each column (non-null values).

# %%
df = pd.read_csv(r"C:\Users\DELL\Documents\Employee-Attrition.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# now let's explore our dataset in a little more detail, especially for our categorical variables and rating numerical variables, to see their different values. The restriction in the condition below is for continuous numerical variables, and because we don't want a very information-intensive display.

# %%
i = 0
for column in df.columns.tolist():
    i += 1
    print('column number : ', i)
    print('name of column : ', column)
    print('type of variable : ', df[column].dtypes)
    if len(df[column].unique()) <= 6 or df[column].dtype == 'object': 
        print('number of each value of the column : \n', df[column].value_counts())
    print('\n')
# Out:
# column number :  1
# name of column :  Age
# type of variable :  int64
#
#
# column number :  2
# name of column :  Attrition
# type of variable :  object
# number of each value of the column :
#  Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64
#
#
# column number :  3
# name of column :  BusinessTravel
# type of variable :  object
# number of each value of the column :
#  BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64
#
#
# column number :  4
# name of column :  DailyRate
# type of variable :  int64
#
#
# column number :  5
# name of column :  Department
# type of variable :  object
# number of each value of the column :
#  Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64
#
#
# column number :  6
# name of column :  DistanceFromHome
# type of variable :  int64
#
#
# column number :  7
# ...

# %% [markdown]
# Now let's explore a comprehensive statistical summary of both numerical and categorical columns in the DataFrame, including count, mean, std (for numerical), and unique, top, and freq (for categorical).

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
df.describe(include='all')
# Out:
#                 Age Attrition BusinessTravel    DailyRate  \
# count   1470.000000      1470           1470  1470.000000
# unique          NaN         2              3          NaN
# top             NaN        No  Travel_Rarely          NaN
# freq            NaN      1233           1043          NaN
# mean      36.923810       NaN            NaN   802.485714
# std        9.135373       NaN            NaN   403.509100
# min       18.000000       NaN            NaN   102.000000
# 25%       30.000000       NaN            NaN   465.000000
# 50%       36.000000       NaN            NaN   802.000000
# 75%       43.000000       NaN            NaN  1157.000000
# max       60.000000       NaN            NaN  1499.000000
#
#                     Department  DistanceFromHome    Education EducationField  \
# count                     1470       1470.000000  1470.000000           1470
# unique                       3               NaN          NaN              6
# ...

# %%
#numerical variables only
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# after understanding our dataset, its different variables, the different values, the different types, the variability of some statistical measures, we will now move on to data cleaning.

# %% [markdown]
# ### Data Preparation : cleaning, labelling, encoding

# %% [markdown]
# Now we need to handle missing data. First, we should check if missing data is represented by symbols like '?' and others, and replace them with np.nan for easier handling.

# %%
missing_symbols = ['?', '-', 'NA', 'N/A']
df.replace(missing_symbols, np.nan, inplace=True)
missing_values = df.isnull().sum()
missing_values
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# Now let's check for duplicated rows and remove them if any are found.

# %%
duplicate_rows = df[df.duplicated()]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [Age, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, EmployeeCount, EmployeeNumber, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, Over18, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager]
# Index: []

# %% [markdown]
# Now that we are sure we don't have any missing values nor duplicated values, we can proceed. As we conclude, the 'Attrition' column is our dependent variable. It would be more appropriate to convert it to a numerical column, with 1 representing 'Yes' and 0 representing 'No'.

# %%
y = df['Attrition']
y.replace({'No': 0, 'Yes': 1}, inplace=True)

# %%
df.head(3)
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# 1                        3    Male          61               2         2
# 2                        4    Male          92               2         1
#
# ...

# %% [markdown]
# here's the list of our numerical values.

# %%
L = [ i for i in df.columns if df[i].dtype == 'int64']
print(L)
# Out:
# ['Age', 'Attrition', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %% [markdown]
# let's re-call the summary of statistics of our numerical variables :

# %%
df.describe()
# Out:
#                Age    Attrition    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810     0.161224   802.485714          9.192517     2.912925
# std       9.135373     0.367863   403.509100          8.106864     1.024165
# min      18.000000     0.000000   102.000000          1.000000     1.000000
# 25%      30.000000     0.000000   465.000000          2.000000     2.000000
# 50%      36.000000     0.000000   802.000000          7.000000     3.000000
# 75%      43.000000     0.000000  1157.000000         14.000000     4.000000
# max      60.000000     1.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1470.0     1470.000000              1470.000000  1470.000000
# mean             1.0     1024.865306                 2.721769    65.891156
# ...

# %% [markdown]
# We notice a significant value for the standard deviation of the DailyRate, MonthlyIncome and MonthlyRate columns. these columns can influence the results of a prediction model later on. they will need to be normalized, in fact i can see that it would be nice to normalize all non- ordinal continuous variables by using StandardScaler to center each feature around its mean, then resizing it so that it has unit variance.
# However, this would influence my visualizations and make absurd values appear to the reader in the visualizations. For this reason, I'll put the code in markdown instead of code for potential future use.

# %% [markdown]
# ```python
#
# continuous_columns = [
#     'Age', 'DailyRate', 'DistanceFromHome', 'HourlyRate', 'MonthlyIncome',
#     'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'TotalWorkingYears',
#     'TrainingTimesLastYear', 'YearsAtCompany', 'YearsInCurrentRole',
#     'YearsSinceLastPromotion', 'YearsWithCurrManager'
# ]
#
# SCALE = StandardScaler()
# df[continuous_columns] = SCALE.fit_transform(df[continuous_columns])
#
#
# ```

# %% [markdown]
# Now let's take another look at our categorial variables and create a list containing all the column names for potential encoding.

# %%
Categorical = []
for column in df.columns.tolist():
    if df[column].dtypes == 'object' :
        Categorical.append(column)
        print('name of column : ', column)
        print('type of variable : ', df[column].dtypes)
        print('number of each value of the column : ', df[column].value_counts())
        print('\n')
print('\n')
# Out:
# name of column :  BusinessTravel
# type of variable :  object
# number of each value of the column :  BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64
#
#
# name of column :  Department
# type of variable :  object
# number of each value of the column :  Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64
#
#
# name of column :  EducationField
# type of variable :  object
# number of each value of the column :  EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64
#
#
# name of column :  Gender
# type of variable :  object
# number of each value of the column :  Gender
# Male      882
# Female    588
# Name: count, dtype: int64
#
#
# name of column :  JobRole
# ...

# %% [markdown]
#  In analyzing our data, I've opted for one-hot encoding for our categorical variables. This will enable us to transform these variables into a format suitable for training machine learning models. Here's a summary of our categorical variables:
#
# BusinessTravel: 3 categories (Travel_Rarely, Travel_Frequently, Non-Travel)
#
# Department: 3 categories (Research & Development, Sales, Human Resources)
#
# EducationField : 6 categories (Life Sciences, Medical, Marketing, Technical Degree, Other, Human Resources)
#
# Gender: 2 categories (Male, Female)
#
# JobRole: 9 categories (Sales Executive, Research Scientist, Laboratory Technician, Manufacturing Director, Healthcare Representative, Manager, Sales Representative, Research Director, Human Resources)
#
# MaritalStatus: 3 categories (Married, Single, Divorced)
#
# OverTime: 2 categories (Yes, No)
#
#
# Each category will be transformed into a binary column where 1 indicates the presence of the category and 0 its absence. This will enable machine learning models to efficiently process this categorical information during analysis and prediction.
#
# I'll put the code in markdown for future potential use. Because this would influence my visualizations.

# %% [markdown]
# ```python
# df_encoded = pd.get_dummies(df,columns = Categorical,dtype=int)
# df_encoded.head()
# ```

# %%
#df_encoded.to_csv('encoded_after_cleaning.csv', index=False)
df.to_csv('not_encoded.csv', index=False)
